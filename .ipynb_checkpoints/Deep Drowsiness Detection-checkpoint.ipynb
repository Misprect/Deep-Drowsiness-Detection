# %% [markdown]
# # Install and Import Dependencies

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5

# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\torch\hub.py:267: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\kshitij pratap tomer/.cache\torch\hub\master.zip
# requirements: YOLOv5 requirements "gitpython" "setuptools>=65.5.1" "wheel>=0.38.0" not found, attempting AutoUpdate...
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gitpython
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ------------------------------------ 184.3/184.3 kB 222.9 kB/s eta 0:00:00
# Collecting setuptools>=65.5.1
#   Downloading setuptools-67.4.0-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 135.0 kB/s eta 0:00:00
# Collecting wheel>=0.38.0
#   Using cached wheel-0.38.4-py3-none-any.whl (36 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      -------------------------------------- 62.7/62.7 kB 420.0 kB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: wheel, smmap, setuptools, gitdb, gitpython
# Successfully installed gitdb-4.0.10 gitpython-3.1.31 setuptools-67.4.0 smmap-5.0.0 wheel-0.38.4
#
# requirements: 3 packages updated per C:\Users\kshitij pratap tomer\.cache\torch\hub\ultralytics_yolov5_master\requirements.txt
# requirements:  Restart runtime or rerun command for updates to take effect
#
# YOLOv5  2023-2-25 Python-3.9.13 torch-1.13.1 CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode=nearest)
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode=nearest)
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(128, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# # Make Detections

# %%
img = 'https://images.unsplash.com/photo-1551385093-ad3fb362dc43?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxzZWFyY2h8Mnx8Zm9vdGJhbGwlMjBtYXRjaHxlbnwwfHwwfHw%3D&w=1000&q=80'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 667x1000 15 persons, 1 sports ball
# Speed: 290.9ms pre-process, 527.9ms inference, 0.0ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[ 14,  20,  36],
#          [ 14,  21,  31],
#          [ 18,  25,  31],
#          ...,
#          [227, 255, 146],
#          [215, 248, 141],
#          [208, 238, 138]],
#
#         [[ 14,  20,  34],
#          [ 14,  21,  31],
#          [ 18,  26,  29],
#          ...,
#          [225, 255, 132],
#          [233, 255, 145],
#          [221, 252, 135]],
#
#         [[ 16,  22,  34],
#          [ 16,  23,  31],
#          [ 19,  27,  30],
#          ...,
#          [210, 238, 115],
#          [245, 255, 156],
#          [203, 232, 116]],
#
#         ...,
#
#         [[ 57,  92,  34],
#          [ 39,  74,  16],
#          [ 34,  69,  11],
#          ...,
#          [105, 139,  45],
#          [109, 143,  48],
#          [ 99, 133,  38]],
#
#         [[ 59,  94,  36],
#          [ 43,  78,  20],
#          [ 39,  74,  16],
#          ...,
#          [105, 139,  44],
#          [109, 143,  48],
#          [102, 136,  41]],
#
#         [[ 61,  96,  38],
#          [ 48,  83,  25],
#          [ 43,  78,  20],
#          ...,
#          [104, 140,  44],
#          [108, 144,  48],
#          [104, 140,  42]]], dtype=uint8)]

# %% [markdown]
# # Real Time Detections

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Train from Scratch

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 20

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for awake
# Collecting images for awake, image number 0
# Collecting images for awake, image number 1
# Collecting images for awake, image number 2
# Collecting images for awake, image number 3
# Collecting images for awake, image number 4
# Collecting images for awake, image number 5
# Collecting images for awake, image number 6
# Collecting images for awake, image number 7
# Collecting images for awake, image number 8
# Collecting images for awake, image number 9
# Collecting images for awake, image number 10
# Collecting images for awake, image number 11
# Collecting images for awake, image number 12
# Collecting images for awake, image number 13
# Collecting images for awake, image number 14
# Collecting images for awake, image number 15
# Collecting images for awake, image number 16
# Collecting images for awake, image number 17
# Collecting images for awake, image number 18
# Collecting images for awake, image number 19
# Collecting images for drowsy
# Collecting images for drowsy, image number 0
# Collecting images for drowsy, image number 1
# Collecting images for drowsy, image number 2
# Collecting images for drowsy, image number 3
# Collecting images for drowsy, image number 4
# Collecting images for drowsy, image number 5
# Collecting images for drowsy, image number 6
# Collecting images for drowsy, image number 7
# Collecting images for drowsy, image number 8
# Collecting images for drowsy, image number 9
# Collecting images for drowsy, image number 10
# Collecting images for drowsy, image number 11
# Collecting images for drowsy, image number 12
# Collecting images for drowsy, image number 13
# Collecting images for drowsy, image number 14
# Collecting images for drowsy, image number 15
# Collecting images for drowsy, image number 16
# Collecting images for drowsy, image number 17
# Collecting images for drowsy, image number 18
# Collecting images for drowsy, image number 19

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# data\images\awake.3ece5986-b479-11ed-9d25-6018953feb89.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# Collecting images for awake
# Collecting images for awake, image number 0
# data\images\awake.404b19a3-b479-11ed-ba92-6018953feb89.jpg
# Collecting images for awake, image number 1
# data\images\awake.404b19a4-b479-11ed-aa7b-6018953feb89.jpg
# Collecting images for awake, image number 2
# data\images\awake.404b19a5-b479-11ed-89ed-6018953feb89.jpg
# Collecting images for awake, image number 3
# data\images\awake.404b19a6-b479-11ed-9fee-6018953feb89.jpg
# Collecting images for awake, image number 4
# data\images\awake.404b19a7-b479-11ed-b0ca-6018953feb89.jpg
# Collecting images for awake, image number 5
# data\images\awake.404b19a8-b479-11ed-9c72-6018953feb89.jpg
# Collecting images for awake, image number 6
# data\images\awake.404b19a9-b479-11ed-989f-6018953feb89.jpg
# Collecting images for awake, image number 7
# data\images\awake.404b19aa-b479-11ed-b0bb-6018953feb89.jpg
# Collecting images for awake, image number 8
# data\images\awake.404b19ab-b479-11ed-b73a-6018953feb89.jpg
# Collecting images for awake, image number 9
# data\images\awake.404b19ac-b479-11ed-8396-6018953feb89.jpg
# Collecting images for awake, image number 10
# data\images\awake.404b19ad-b479-11ed-9b15-6018953feb89.jpg
# Collecting images for awake, image number 11
# data\images\awake.404b19ae-b479-11ed-9426-6018953feb89.jpg
# Collecting images for awake, image number 12
# data\images\awake.404b19af-b479-11ed-bf55-6018953feb89.jpg
# Collecting images for awake, image number 13
# data\images\awake.404b19b0-b479-11ed-ba69-6018953feb89.jpg
# Collecting images for awake, image number 14
# data\images\awake.404b19b1-b479-11ed-b044-6018953feb89.jpg
# Collecting images for awake, image number 15
# data\images\awake.404b19b2-b479-11ed-8140-6018953feb89.jpg
# Collecting images for awake, image number 16
# data\images\awake.404b19b3-b479-11ed-bad4-6018953feb89.jpg
# Collecting images for awake, image number 17
# data\images\awake.404b19b4-b479-11ed-89be-6018953feb89.jpg
# Collecting images for awake, image number 18
# data\images\awake.404b19b5-b479-11ed-92d2-6018953feb89.jpg
# Collecting images for awake, image number 19
# data\images\awake.404b19b6-b479-11ed-b474-6018953feb89.jpg
# Collecting images for drowsy
# Collecting images for drowsy, image number 0
# data\images\drowsy.404b19b7-b479-11ed-9ba7-6018953feb89.jpg
# Collecting images for drowsy, image number 1
# data\images\drowsy.404b19b8-b479-11ed-a3e6-6018953feb89.jpg
# Collecting images for drowsy, image number 2
# data\images\drowsy.404b2e76-b479-11ed-bdc3-6018953feb89.jpg
# Collecting images for drowsy, image number 3
# data\images\drowsy.404b2e77-b479-11ed-b72c-6018953feb89.jpg
# Collecting images for drowsy, image number 4
# data\images\drowsy.404b2e78-b479-11ed-b878-6018953feb89.jpg
# Collecting images for drowsy, image number 5
# data\images\drowsy.404b2e79-b479-11ed-9a06-6018953feb89.jpg
# Collecting images for drowsy, image number 6
# data\images\drowsy.404b2e7a-b479-11ed-aee0-6018953feb89.jpg
# Collecting images for drowsy, image number 7
# data\images\drowsy.404b2e7b-b479-11ed-87d7-6018953feb89.jpg
# Collecting images for drowsy, image number 8
# data\images\drowsy.404b2e7c-b479-11ed-8000-6018953feb89.jpg
# Collecting images for drowsy, image number 9
# data\images\drowsy.404b2e7d-b479-11ed-9d87-6018953feb89.jpg
# Collecting images for drowsy, image number 10
# data\images\drowsy.404b2e7e-b479-11ed-bd4f-6018953feb89.jpg
# Collecting images for drowsy, image number 11
# data\images\drowsy.404b2e7f-b479-11ed-8e9b-6018953feb89.jpg
# Collecting images for drowsy, image number 12
# data\images\drowsy.404b2e80-b479-11ed-a92a-6018953feb89.jpg
# Collecting images for drowsy, image number 13
# data\images\drowsy.404b2e81-b479-11ed-ac2f-6018953feb89.jpg
# Collecting images for drowsy, image number 14
# data\images\drowsy.404b2e82-b479-11ed-967b-6018953feb89.jpg
# Collecting images for drowsy, image number 15
# data\images\drowsy.404b2e83-b479-11ed-99b6-6018953feb89.jpg
# Collecting images for drowsy, image number 16
# data\images\drowsy.404b2e84-b479-11ed-a77e-6018953feb89.jpg
# Collecting images for drowsy, image number 17
# data\images\drowsy.404b2e85-b479-11ed-bb77-6018953feb89.jpg
# Collecting images for drowsy, image number 18
# data\images\drowsy.404b2e86-b479-11ed-b12a-6018953feb89.jpg
# Collecting images for drowsy, image number 19
# data\images\drowsy.404b2e87-b479-11ed-b5e6-6018953feb89.jpg

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyqt5 in c:\users\kshitij pratap tomer\appdata\roaming\python\python39\site-packages (5.15.9)
# Requirement already satisfied: lxml in c:\users\kshitij pratap tomer\appdata\roaming\python\python39\site-packages (4.9.2)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in c:\users\kshitij pratap tomer\appdata\roaming\python\python39\site-packages (from pyqt5) (5.15.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.11 in c:\users\kshitij pratap tomer\appdata\roaming\python\python39\site-packages (from pyqt5) (12.11.1)

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2

# %% [markdown]
# # Load Custom Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path=' yolov5/runs/train/exp/weights/last.pt',force_reload=True,_verbose=False)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\kshitij pratap tomer/.cache\torch\hub\master.zip
# YOLOv5  2023-2-25 Python-3.9.13 torch-1.13.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'awake.8cabb7a6-b47a-11ed-8ea5-6018953feb89.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 awake
# Speed: 16.2ms pre-process, 177.4ms inference, 0.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
